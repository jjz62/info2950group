# %% [markdown]
# # Jupyter Notebook

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %load_ext sql

# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb:///:memory:

# %%
twenty_twenty_one = pd.read_csv('data/2021_ecr.csv')
twenty_twenty_one
# Out:
#      Unnamed: 0               Player Team   Rank    Pos   Bye   Best  Worst  \
# 0             1  Christian McCaffrey  CAR    1.0    RB1  13.0    1.0    7.0
# 1             2       Saquon Barkley  NYG    2.0    RB2  11.0    1.0    6.0
# 2             3      Ezekiel Elliott  DAL    3.0    RB3  10.0    1.0   11.0
# 3             4        Derrick Henry  TEN    4.0    RB4   7.0    2.0   12.0
# 4             6          Dalvin Cook  MIN    5.0    RB5   7.0    2.0   20.0
# ..          ...                  ...  ...    ...    ...   ...    ...    ...
# 517         533       Elijah McGuire   KC  514.0  RB146  10.0  366.0  382.0
# 518         534       Trenton Cannon  CAR  515.0  RB147  13.0  365.0  384.0
# 519         535       Robert Griffin  BAL  516.0   QB47   8.0  371.0  381.0
# 520         536       Phillip Walker  CAR  517.0   QB48  13.0  367.0  386.0
# 521         537        Byron Pringle   KC  518.0  WR170  10.0  373.0  383.0
#
#        Avg  Std Dev  ADP
# 0      1.2      0.7  1.0
# ...
