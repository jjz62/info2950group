# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
#wide receiver stats
wr_stats_2021 = pd.read_csv('data/post-season data/FantasyPros_Fantasy_Football_Advanced_Stats_Report_WR_2021.csv')
wr_stats_2021['Year'] = '2021'
wr_stats_2020 = pd.read_csv('data/post-season data/FantasyPros_Fantasy_Football_Advanced_Stats_Report_WR_2020.csv')
wr_stats_2020['Year'] = '2020'
wr_stats_2019 = pd.read_csv('data/post-season data/FantasyPros_Fantasy_Football_Advanced_Stats_Report_WR_2019.csv')
wr_stats_2019['Year'] = '2019'
wr_stats_2018 = pd.read_csv('data/post-season data/FantasyPros_Fantasy_Football_Advanced_Stats_Report_WR_2018.csv')
wr_stats_2018['Year'] = '2018'
wr_stats_2017 = pd.read_csv('data/post-season data/FantasyPros_Fantasy_Football_Advanced_Stats_Report_WR_2017.csv')
wr_stats_2017['Year'] = '2017'
wr_stats_2016 = pd.read_csv('data/post-season data/FantasyPros_Fantasy_Football_Advanced_Stats_Report_WR_2016.csv')
wr_stats_2016['Year'] = '2016'
wr_stats_2015 = pd.read_csv('data/post-season data/FantasyPros_Fantasy_Football_Advanced_Stats_Report_WR_2015.csv')
wr_stats_2015['Year'] = '2015'
wr_stats_2014 = pd.read_csv('data/post-season data/FantasyPros_Fantasy_Football_Advanced_Stats_Report_WR_2014.csv')
wr_stats_2014['Year'] = '2014'
wr_stats_2013 = pd.read_csv('data/post-season data/FantasyPros_Fantasy_Football_Advanced_Stats_Report_WR_2013.csv')
wr_stats_2013['Year'] = '2013'

wr_table = pd.concat([wr_stats_2021,wr_stats_2020,wr_stats_2019,wr_stats_2018,wr_stats_2017,wr_stats_2016,wr_stats_2015,wr_stats_2014,wr_stats_2013])
wr_table = wr_table[["Player", "Year", "Y/R", "YBC/R", "AIR/R", "YAC/R", "YACON/R", "10+ YDS", "20+ YDS", "30+ YDS", "40+ YDS", "50+ YDS"]]
wr_table['Player'] = wr_table['Player'].str.replace(r"\(.*\)","")
wr_table['Player'] = wr_table['Player'].str.strip()
# Out:
# /var/folders/lb/m8dvt67d5_z6bq94369zh96c0000gn/T/ipykernel_11783/2316881158.py:23: FutureWarning: The default value of regex will change from True to False in a future version.
#   wr_table['Player'] = wr_table['Player'].str.replace(r"\(.*\)","")

# %%
wr_table['Player'].tolist()
# Out:
# ['Cooper Kupp',
#  'Deebo Samuel',
#  "Ja'Marr Chase",
#  'Justin Jefferson',
#  'Davante Adams',
#  'Mike Evans',
#  'Tyreek Hill',
#  'Stefon Diggs',
#  'Mike Williams',
#  'DK Metcalf',
#  'Tyler Lockett',
#  'Diontae Johnson',
#  'Hunter Renfrow',
#  'CeeDee Lamb',
#  'Keenan Allen',
#  'Michael Pittman Jr.',
#  'Tee Higgins',
#  'DJ Moore',
#  'Chris Godwin',
#  'Jaylen Waddle',
#  'Brandin Cooks',
#  'Darnell Mooney',
#  'Amon-Ra St. Brown',
#  'Terry McLaurin',
#  'Marquise Brown',
#  'Amari Cooper',
#  'Adam Thielen',
#  'Christian Kirk',
#  'Kendrick Bourne',
#  'DeVonta Smith',
#  'Van Jefferson',
#  'A.J. Brown',
#  'Tyler Boyd',
#  'Brandon Aiyuk',
#  'K.J. Osborn',
#  'Chase Claypool',
#  'Marvin Jones Jr.',
#  'Marquez Callaway',
#  'DeAndre Hopkins',
#  'Tim Patrick',
#  'Jakobi Meyers',
#  'Cedrick Wilson Jr.',
#  'A.J. Green',
#  'Allen Lazard',
#  'Russell Gage',
#  'Elijah Moore',
#  'Courtland Sutton',
#  'Robert Woods',
#  'Gabe Davis',
#  'Emmanuel Sanders',
#  'Robbie Anderson',
#  'Odell Beckham Jr.',
#  'Byron Pringle',
#  'Kalif Raymond',
#  'Mecole Hardman',
#  'Jarvis Landry',
#  'Antonio Brown',
#  'Cole Beasley',
#  'Deonte Harty',
#  'Donovan Peoples-Jones',
#  'Braxton Berrios',
#  'Bryan Edwards',
#  'Quez Watkins',
#  'Corey Davis',
#  'Nick Westbrook-Ikhine',
#  'Nelson Agholor',
#  'Jalen Guyton',
#  'Randall Cobb',
#  'Laviska Shenault Jr.',
#  'DeVante Parker',
#  'DeAndre Carter',
#  'Freddie Swain',
#  'Marquez Valdes-Scantling',
#  'Henry Ruggs III',
#  'Joshua Palmer',
#  'Zay Jones',
#  'Olamide Zaccheaus',
#  'Jamison Crowder',
#  'Jauan Jennings',
#  'Rashod Bateman',
#  'Zach Pascal',
#  'Michael Gallup',
#  'DeSean Jackson',
#  "Tre'Quan Smith",
#  'Rondale Moore',
#  'Kenny Golladay',
#  'Jamal Agnew',
#  'Josh Reynolds',
#  'T.Y. Hilton',
#  'Keelan Cole Sr.',
#  'Nico Collins',
#  'Laquon Treadwell',
#  'Julio Jones',
#  'Allen Robinson II',
#  'Jerry Jeudy',
#  'Mack Hollins',
#  'Jalen Reagor',
#  'Danny Amendola',
#  'Demarcus Robinson',
#  'Devin Duvernay',
#  'Sammy Watkins',
#  'Kadarius Toney',
#  'Chris Conley',
#  'Darius Slayton',
#  'James Washington',
#  'Sterling Shepard',
#  'Calvin Ridley',
#  'Damiere Byrd',
#  'Antoine Wesley',
#  'Adam Humphries',
#  'Marquise Goodwin',
#  "Lil'Jordan Humphrey",
#  'Tyler Johnson',
#  'Chester Rogers',
#  'Chris Moore',
#  'Cyril Grayson Jr.',
#  'Quintez Cephus',
#  'Cam Sims',
#  'Rashard Higgins',
#  'Malik Turner',
#  'Isaiah McKenzie',
#  'Ashton Dulin',
#  'Brandon Zylstra',
#  'John Ross',
#  'Jakeem Grant Sr.',
#  'Isaiah Ford',
#  'Greg Ward',
#  'D.J. Chark Jr.',
#  'Tavon Austin',
#  'Ray-Ray McCloud',
#  'Ihmir Smith-Marsette',
#  'Kendall Hinton',
#  'Anthony Schwartz',
#  'Tajae Sharpe',
#  'Albert Wilson',
#  'Breshad Perriman',
#  'Parris Campbell',
#  'James Proche II',
#  'JuJu Smith-Schuster',
#  'Noah Brown',
#  'Dee Eskridge',
#  'Mohamed Sanu Sr.',
#  'KhaDarel Hodge',
#  "N'Keal Harry",
#  'Kristian Wilkerson',
#  'Dyami Brown',
#  'Terrace Marshall Jr.',
#  'Marcus Johnson',
#  'Dante Pettis',
#  'Trent Sherfield',
#  'Scotty Miller',
#  'Denzel Mims',
#  'Ben Skowronek',
#  'Kenny Stills',
#  'Tom Kennedy',
#  'Equanimeous St. Brown',
#  'Jeff Smith',
#  'Phillip Dorsett II',
#  'Dez Fitzpatrick',
#  'Collin Johnson',
#  'Trinity Benson',
#  'Chris Hogan',
#  'Shi Smith',
#  'Auden Tate',
#  'Josh Gordon',
#  'Cameron Batson',
#  'Anthony Miller',
#  'Dezmon Patmon',
#  'Preston Williams',
#  'K.J. Hamler',
#  'Dede Westbrook',
#  "Ja'Marcus Bradley",
#  'Dax Milne',
#  'Penny Hart',
#  'C.J. Board',
#  'Jason Moore Jr.',
#  'Amari Rodgers',
#  'Alex Erickson',
#  'Jaelon Darden',
#  'Mike Thomas',
#  'William Fuller V',
#  'Greg Dortch',
#  'Willie Snead IV',
#  'Kevin White',
#  'Juwann Winfree',
#  'Curtis Samuel',
#  'J.J. Arcega-Whiteside',
#  'D.J. Montgomery',
#  'Pharoh Cooper',
#  'Trenton Irwin',
#  'Cody Hollister',
#  'Cody White',
#  'KJ Hill Jr.',
#  'Jake Kumerow',
#  'Christian Blake',
#  'Marcus Kemp',
#  'Dazz Newsome',
#  'Tylan Wallace',
#  'David Sills V',
#  'Keith Kirkwood',
#  'Tyron Johnson',
#  'Stanley Morgan Jr.',
#  'Frank Darby',
#  'Racey McMath',
#  'Travis Benjamin',
#  'Diontae Spencer',
#  nan,
#  nan,
#  'Davante Adams',
#  'Tyreek Hill',
#  'Stefon Diggs',
#  'Calvin Ridley',
#  'DK Metcalf',
#  'Justin Jefferson',
#  'Adam Thielen',
#  'Mike Evans',
#  'A.J. Brown',
#  'DeAndre Hopkins',
#  'Tyler Lockett',
#  'Allen Robinson II',
#  'Robert Woods',
#  'Chase Claypool',
#  'Marvin Jones Jr.',
#  'Brandin Cooks',
#  'DJ Moore',
#  'Keenan Allen',
#  'Amari Cooper',
#  'CeeDee Lamb',
#  'Nelson Agholor',
#  'JuJu Smith-Schuster',
#  'Terry McLaurin',
#  'William Fuller V',
#  'Curtis Samuel',
#  'Diontae Johnson',
#  'Robbie Anderson',
#  'Tee Higgins',
#  'Corey Davis',
#  'Chris Godwin',
#  'Cole Beasley',
#  'Marquise Brown',
#  'Brandon Aiyuk',
#  'Cooper Kupp',
#  'Jarvis Landry',
#  'Michael Gallup',
#  'Tyler Boyd',
#  'Jamison Crowder',
#  'Tim Patrick',
#  'Russell Gage',
#  'T.Y. Hilton',
#  'Mike Williams',
#  'Jerry Jeudy',
#  'Marquez Valdes-Scantling',
#  'Emmanuel Sanders',
#  'DeVante Parker',
#  'Gabe Davis',
#  'D.J. Chark Jr.',
#  'Keelan Cole Sr.',
#  'Laviska Shenault Jr.',
#  'Christian Kirk',
#  'Sterling Shepard',
#  'Julio Jones',
#  'Zach Pascal',
#  'Darnell Mooney',
#  'Darius Slayton',
#  'Mecole Hardman',
#  'Rashard Higgins',
#  'David Moore',
#  'Jakobi Meyers',
#  'Kendrick Bourne',
#  'Greg Ward',
#  'Travis Fulgham',
#  'Hunter Renfrow',
#  'Josh Reynolds',
#  'Antonio Brown',
#  'Isaiah McKenzie',
#  'Scotty Miller',
#  'James Washington',
#  'Breshad Perriman',
#  'Jalen Guyton',
#  "Tre'Quan Smith",
#  'Damiere Byrd',
#  'Allen Lazard',
#  'A.J. Green',
#  'Odell Beckham Jr.',
#  'John Brown',
#  'Demarcus Robinson',
#  'Randall Cobb',
#  'Willie Snead IV',
#  'Danny Amendola',
#  'Braxton Berrios',
#  'K.J. Hamler',
#  'Anthony Miller',
#  'Tyron Johnson',
#  'Michael Pittman Jr.',
#  'Henry Ruggs III',
#  'Chris Conley',
#  'Preston Williams',
#  'Jalen Reagor',
#  'Cam Sims',
#  'Keke Coutee',
#  'Golden Tate',
#  'Sammy Watkins',
#  'Jakeem Grant Sr.',
#  'Miles Boykin',
#  'Deebo Samuel',
#  'Quintez Cephus',
#  'Larry Fitzgerald',
#  'Kenny Golladay',
#  'Donovan Peoples-Jones',
#  'Michael Thomas',
#  'Marvin Hall',
#  'Richie James Jr.',
#  'Collin Johnson',
#  "N'Keal Harry",
#  'DaeSean Hamilton',
#  'Denzel Mims',
#  'Julian Edelman',
#  'Adam Humphries',
#  'Cedrick Wilson Jr.',
#  'Andy Isabella',
#  'Olamide Zaccheaus',
#  'Devin Duvernay',
#  'DeSean Jackson',
#  'Steven Sims Jr.',
#  'Chad Beebe',
#  'Chad Hansen',
#  'Tyler Johnson',
#  'Dontrelle Inman',
#  'Byron Pringle',
#  'Freddie Swain',
#  'Van Jefferson',
#  'Deonte Harty',
#  'Isaiah Ford',
#  'Mohamed Sanu Sr.',
#  'Lynn Bowden Jr.',
#  'Marcus Johnson',
#  'Bryan Edwards',
#  'Zay Jones',
#  'Mack Hollins',
#  'Marquez Callaway',
#  'Bisi Johnson',
#  'Gunner Olszewski',
#  'Kenny Stills',
#  'Isaiah Wright',
#  'John Hightower',
#  'Equanimeous St. Brown',
#  'Kalif Raymond',
#  'Cameron Batson',
#  'KhaDarel Hodge',
#  'Brandon Powell',
#  'Alshon Jeffery',
#  'Mike Thomas',
#  'KeeSean Johnson',
#  'Laquon Treadwell',
#  'Dez Bryant',
#  'Jeff Smith',
#  'Quez Watkins',
#  'Jamal Agnew',
#  'Noah Brown',
#  'Malcolm Perry',
#  'Auden Tate',
#  'Christian Blake',
#  'Malik Taylor',
#  'DeMichael Harris',
#  'Ray-Ray McCloud',
#  'Chris Hogan',
#  'Dante Pettis',
#  'Javon Wims',
#  'Alex Erickson',
#  "Lil'Jordan Humphrey",
#  'J.J. Arcega-Whiteside',
#  'Diontae Spencer',
#  'C.J. Board',
#  'Justin Watson',
#  'Austin Mack',
#  'Austin Carr',
#  'Parris Campbell',
#  'Trent Taylor',
#  'Pharoh Cooper',
#  'Courtland Sutton',
#  'Ashton Dulin',
#  'Damion Ratley',
#  'Tyrie Cleveland',
#  'Steven Mitchell Jr.',
#  "Ja'Marcus Bradley",
#  'Jaydon Mickens',
#  'KJ Hill Jr.',
#  'Nick Westbrook-Ikhine',
#  'Trent Sherfield',
#  'River Cracraft',
#  'Ted Ginn Jr.',
#  'Riley Ridley',
#  'Robert Foster',
#  'Brandon Zylstra',
#  'Terry Godwin',
#  'Lawrence Cager',
#  'Seth Roberts',
#  'Josh Malone',
#  'Darrius Shepherd',
#  'Antonio Gandy-Golden',
#  'Antonio Callaway',
#  'Deontay Burnett',
#  'John Ross',
#  'Bennie Fowler III',
#  'Tavon Austin',
#  'Andre Roberts',
#  nan,
#  nan,
#  'Michael Thomas',
#  'Chris Godwin',
#  'Kenny Golladay',
#  'Cooper Kupp',
#  'Julio Jones',
#  'DeVante Parker',
#  'Amari Cooper',
#  'Mike Evans',
#  'DeAndre Hopkins',
#  'A.J. Brown',
#  'Keenan Allen',
#  'Allen Robinson II',
#  'Julian Edelman',
#  'Jarvis Landry',
#  'Tyler Lockett',
#  'D.J. Chark Jr.',
#  'Courtland Sutton',
#  'Stefon Diggs',
#  'John Brown',
#  'Michael Gallup',
#  'DJ Moore',
#  'Robert Woods',
#  'Calvin Ridley',
#  'Terry McLaurin',
#  'Tyler Boyd',
#  'Deebo Samuel',
#  'Marvin Jones Jr.',
#  'Tyreek Hill',
#  'Davante Adams',
#  'DK Metcalf',
#  'Odell Beckham Jr.',
#  'Emmanuel Sanders',
#  'Darius Slayton',
#  'Jamison Crowder',
#  'Cole Beasley',
#  'Curtis Samuel',
#  'Mike Williams',
#  'Robbie Anderson',
#  'Chris Conley',
#  'Diontae Johnson',
#  'Golden Tate',
#  'Larry Fitzgerald',
#  'Breshad Perriman',
#  'Tyrell Williams',
#  'Marquise Brown',
#  'Christian Kirk',
#  'Randall Cobb',
#  'Zach Pascal',
#  'Mecole Hardman',
#  'Dede Westbrook',
#  'James Washington',
#  'Sammy Watkins',
#  'William Fuller V',
#  'Sterling Shepard',
#  'Hunter Renfrow',
#  'Adam Thielen',
#  'T.Y. Hilton',
#  'Kenny Stills',
#  'Alshon Jeffery',
#  'Danny Amendola',
#  'Anthony Miller',
#  'Steven Sims Jr.',
#  'Brandin Cooks',
#  'Corey Davis',
#  'Phillip Dorsett II',
#  'JuJu Smith-Schuster',
#  'Demarcus Robinson',
#  'Kendrick Bourne',
#  'Allen Lazard',
#  'John Ross',
#  'Mohamed Sanu Sr.',
#  'Willie Snead IV',
#  'Auden Tate',
#  'Taylor Gabriel',
#  'Preston Williams',
#  'Marquez Valdes-Scantling',
#  'Tajae Sharpe',
#  'Ted Ginn Jr.',
#  'Nelson Agholor',
#  'Keelan Cole Sr.',
#  "Tre'Quan Smith",
#  'Alex Erickson',
#  'Allen Hurns',
#  'Russell Gage',
#  'Adam Humphries',
#  'Demaryius Thomas',
#  'Bisi Johnson',
#  'Josh Gordon',
#  'Albert Wilson',
#  'David Moore',
#  'Cody Latimer',
#  'Geronimo Allison',
#  'Josh Reynolds',
#  'Damiere Byrd',
#  'Marcus Johnson',
#  'Seth Roberts',
#  'Miles Boykin',
#  'Kelvin Harmon',
#  'Paul Richardson Jr.',
#  'Isaiah McKenzie',
#  'Jakobi Meyers',
#  'DaeSean Hamilton',
#  'Tavon Austin',
#  'Marvin Hall',
#  'Jaron Brown',
#  'Greg Ward',
#  'Vyncint Smith',
#  'Keke Coutee',
#  'Pharoh Cooper',
#  'Malik Turner',
#  'Chester Rogers',
#  'Jarius Wright',
#  'DeSean Jackson',
#  'Jake Kumerow',
#  'Justin Watson',
#  'Scotty Miller',
#  "N'Keal Harry",
#  'Jakeem Grant Sr.',
#  'Andy Isabella',
#  'Marquise Goodwin',
#  'Damion Ratley',
#  'Trey Quinn',
#  'Isaiah Ford',
#  'KeeSean Johnson',
#  'Javon Wims',
#  'Laquon Treadwell',
#  'Dante Pettis',
#  'Bennie Fowler III',
#  'Byron Pringle',
#  'J.J. Arcega-Whiteside',
#  'Duke Williams',
#  'Zay Jones',
#  'Tim Patrick',
#  'Kalif Raymond',
#  'Richie James Jr.',
#  'Trevor Davis',
#  'Parris Campbell',
#  'Justin Hardy',
#  'Dontrelle Inman',
#  'Olamide Zaccheaus',
#  'Devin Smith',
#  'DeAndre Carter',
#  'Keelan Doss',
#  'Mack Hollins',
#  'Deon Cain',
#  'Antonio Brown',
#  'Rashard Higgins',
#  'Brandon Zylstra',
#  'T.J. Jones',
#  'Marcell Ateman',
#  'J.J. Nelson',
#  'Deonte Harty',
#  'Braxton Berrios',
#  'Robert Foster',
#  'Christian Blake',
#  'Antonio Callaway',
#  'Damion Willis',
#  'Trent Sherfield',
#  'KhaDarel Hodge',
#  'Riley Ridley',
#  'Chris Hogan',
#  'Tevin Jones',
#  'Chris Lacy',
#  'Andre Patton',
#  'DeAndrew White',
#  'Deontay Burnett',
#  'Cedrick Wilson Jr.',
#  'Alexander Hollins',
#  'Jason Moore Jr.',
#  'Geremy Davis',
#  'Steven Mitchell Jr.',
#  'Ishmael Hyman',
#  'Jordan Matthews',
#  'Devin Funchess',
#  'C.J. Board',
#  'Johnny Holton',
#  'Travis Benjamin',
#  'Cody Core',
#  'Ryan Switzer',
#  'Andre Roberts',
#  'Russell Shepard',
#  'Michael Crabtree',
#  'Chris Moore',
#  'Marqise Lee',
#  'Stanley Morgan Jr.',
#  'Donte Moncrief',
#  'Darius Jennings',
#  'Diontae Spencer',
#  'Robert Davis',
#  'Bobo Wilson',
#  'Mike Thomas',
#  'Gunner Olszewski',
#  'Ryan Grant',
#  'Austin Carr',
#  nan,
#  nan,
#  'Tyreek Hill',
#  'Antonio Brown',
#  'Davante Adams',
#  'DeAndre Hopkins',
#  'Julio Jones',
#  'Mike Evans',
#  'Adam Thielen',
#  'Michael Thomas',
#  'JuJu Smith-Schuster',
#  'Robert Woods',
#  'Tyler Lockett',
#  'Stefon Diggs',
#  'Brandin Cooks',
#  'Keenan Allen',
#  'T.Y. Hilton',
#  'Odell Beckham Jr.',
#  'Tyler Boyd',
#  'Calvin Ridley',
#  'Amari Cooper',
#  'Mike Williams',
#  'Kenny Golladay',
#  'Jarvis Landry',
#  'Julian Edelman',
#  'Emmanuel Sanders',
#  'Chris Godwin',
#  'Alshon Jeffery',
#  'Corey Davis',
#  'Larry Fitzgerald',
#  'Sterling Shepard',
#  'Mohamed Sanu Sr.',
#  'Adam Humphries',
#  'DeSean Jackson',
#  'Zay Jones',
#  'Golden Tate',
#  'Dede Westbrook',
#  'Robbie Anderson',
#  'A.J. Green',
#  'DJ Moore',
#  'John Brown',
#  'Nelson Agholor',
#  'Allen Robinson II',
#  'Curtis Samuel',
#  'Josh Gordon',
#  'Demaryius Thomas',
#  'Kenny Stills',
#  'Tyrell Williams',
#  'Cooper Kupp',
#  'Courtland Sutton',
#  'Jordy Nelson',
#  'Doug Baldwin',
#  'Antonio Callaway',
#  'Anthony Miller',
#  'Cole Beasley',
#  'Taylor Gabriel',
#  'Donte Moncrief',
#  'Marvin Jones Jr.',
#  'Christian Kirk',
#  'Rashard Higgins',
#  'Devin Funchess',
#  'Michael Crabtree',
#  'Dante Pettis',
#  'Sammy Watkins',
#  'David Moore',
#  'William Fuller V',
#  'Marquez Valdes-Scantling',
#  'Kendrick Bourne',
#  "Tre'Quan Smith",
#  'Willie Snead IV',
#  'Robert Foster',
#  'Chris Hogan',
#  'Josh Reynolds',
#  'Albert Wilson',
#  'Danny Amendola',
#  'Josh Doctson',
#  'Michael Gallup',
#  'Marquise Goodwin',
#  'Chester Rogers',
#  'John Ross',
#  'Seth Roberts',
#  'Chris Conley',
#  'Jarius Wright',
#  'Jamison Crowder',
#  'Aldrick Robinson',
#  'Demarcus Robinson',
#  'Keelan Cole Sr.',
#  'Taywan Taylor',
#  'Phillip Dorsett II',
#  'Quincy Enunwa',
#  'Dontrelle Inman',
#  'Randall Cobb',
#  'Jaron Brown',
#  'Breshad Perriman',
#  'Tajae Sharpe',
#  'Kelvin Benjamin',
#  'Jermaine Kearse',
#  'Geronimo Allison',
#  'Jordan Matthews',
#  'Allen Hurns',
#  'Zach Pascal',
#  'Ryan Grant',
#  'Jakeem Grant Sr.',
#  'Paul Richardson Jr.',
#  'Tim Patrick',
#  'Terrelle Pryor Sr.',
#  'DeVante Parker',
#  'DaeSean Hamilton',
#  'Laquon Treadwell',
#  'Ted Ginn Jr.',
#  'Keke Coutee',
#  'Pierre Garcon',
#  'Isaiah McKenzie',
#  'Ryan Switzer',
#  'Equanimeous St. Brown',
#  'Torrey Smith',
#  'Keith Kirkwood',
#  'Tavon Austin',
#  'Maurice Harris',
#  'T.J. Jones',
#  'Russell Shepard',
#  'Trent Taylor',
#  'Travis Benjamin',
#  'Bruce Ellington',
#  'James Washington',
#  'Chris Moore',
#  'Trent Sherfield',
#  'Martavis Bryant',
#  'Bennie Fowler III',
#  'Brandon LaFell',
#  'Justin Hardy',
#  'Cody Latimer',
#  'Chad Williams',
#  'Cody Core',
#  'Austin Carr',
#  'Marcell Ateman',
#  'Marvin Hall',
#  'DeAndre Carter',
#  'Josh Bellamy',
#  'Brandon Marshall',
#  'Michael Floyd',
#  'Richie James Jr.',
#  'Alex Erickson',
#  'Leonte Carroo',
#  'Jake Kumerow',
#  'Andre Holmes',
#  'Deonte Thompson',
#  'Marcus Johnson',
#  'D.J. Chark Jr.',
#  'Cameron Meredith',
#  'Vyncint Smith',
#  'Damion Ratley',
#  'Deontay Burnett',
#  'Andy Jones',
#  'Andre Roberts',
#  'Trey Quinn',
#  'Brandon Powell',
#  'Brice Butler',
#  'Darius Jennings',
#  'Tommylee Lewis',
#  "De'Anthony Thomas",
#  'Eli Rogers',
#  'Kevin White',
#  'Cameron Batson',
#  'Corey Coleman',
#  'J.J. Nelson',
#  'Russell Gage',
#  'Derrick Willies',
#  'Noah Brown',
#  'Kamar Aiken',
#  'Dwayne Harris',
#  'Bobo Wilson',
#  'Jawill Davis',
#  'Rashad Greene',
#  'Chad Beebe',
#  'Jalen Tolliver',
#  'Auden Tate',
#  'Javon Wims',
#  'Rishard Matthews',
#  'Justin Hunter',
#  'Ray-Ray McCloud',
#  'Brian Quick',
#  'Nick Williams',
#  'Josh Malone',
#  'Victor Bolden Jr.',
#  'Jeremy Kerley',
#  nan,
#  nan,
#  'DeAndre Hopkins',
#  'Antonio Brown',
#  'Keenan Allen',
#  'Tyreek Hill',
#  'Marvin Jones Jr.',
#  'Julio Jones',
#  'Brandin Cooks',
#  'Michael Thomas',
#  'Larry Fitzgerald',
#  'A.J. Green',
#  'Adam Thielen',
#  'Davante Adams',
#  'Doug Baldwin',
#  'Jarvis Landry',
#  'Alshon Jeffery',
#  'Robbie Anderson',
#  'Stefon Diggs',
#  'JuJu Smith-Schuster',
#  'Golden Tate',
#  'Mike Evans',
#  'Devin Funchess',
#  'Nelson Agholor',
#  'Demaryius Thomas',
#  'T.Y. Hilton',
#  'Dez Bryant',
#  'Kenny Stills',
#  'Cooper Kupp',
#  'Michael Crabtree',
#  'Marquise Goodwin',
#  'Jermaine Kearse',
#  'Amari Cooper',
#  'Mohamed Sanu Sr.',
#  'Robert Woods',
#  'Sammy Watkins',
#  'Ted Ginn Jr.',
#  'Paul Richardson Jr.',
#  'Rishard Matthews',
#  'Mike Wallace',
#  'Tyrell Williams',
#  'Jamison Crowder',
#  'Randall Cobb',
#  'Marqise Lee',
#  'Keelan Cole Sr.',
#  'Travis Benjamin',
#  'DeSean Jackson',
#  'Kelvin Benjamin',
#  'Sterling Shepard',
#  'William Fuller V',
#  'Josh Doctson',
#  'Jordy Nelson',
#  'Martavis Bryant',
#  'Ryan Grant',
#  'Danny Amendola',
#  'Chris Hogan',
#  'Albert Wilson',
#  'Tyler Lockett',
#  'DeVante Parker',
#  'Brandon LaFell',
#  'Jaron Brown',
#  'Adam Humphries',
#  'Emmanuel Sanders',
#  'Kendall Wright',
#  'Deonte Thompson',
#  'Kenny Golladay',
#  'J.J. Nelson',
#  'Eric Decker',
#  'Jeremy Maclin',
#  'Allen Hurns',
#  'Chris Godwin',
#  'Terrance Williams',
#  'Cole Beasley',
#  'Torrey Smith',
#  'Roger Lewis',
#  'Trent Taylor',
#  'Bennie Fowler III',
#  'Donte Moncrief',
#  'Brandon Coleman',
#  'Pierre Garcon',
#  'Brice Butler',
#  'Odell Beckham Jr.',
#  'John Brown',
#  'Taylor Gabriel',
#  'T.J. Jones',
#  'Seth Roberts',
#  'Bruce Ellington',
#  'Josh Bellamy',
#  'Zay Jones',
#  'Cody Latimer',
#  'Corey Coleman',
#  'Tavarres King',
#  'Chris Moore',
#  'Rashard Higgins',
#  'Dontrelle Inman',
#  'Justin Hardy',
#  'Dede Westbrook',
#  'Josh Gordon',
#  'Aldrick Robinson',
#  'Kenny Britt',
#  'Johnny Holton',
#  'Ricardo Louis',
#  'Corey Davis',
#  'Chester Rogers',
#  'Tyler Boyd',
#  'Taywan Taylor',
#  'Jordan Matthews',
#  'Jarius Wright',
#  'Jakeem Grant Sr.',
#  'Andre Holmes',
#  'Terrelle Pryor Sr.',
#  'Tavon Austin',
#  'Mack Hollins',
#  'Russell Shepard',
#  'Michael Campanaro',
#  "De'Anthony Thomas",
#  'Kendrick Bourne',
#  'Jeremy Kerley',
#  'Damiere Byrd',
#  'Alex Erickson',
#  'Geronimo Allison',
#  'Braxton Miller',
#  'Demarcus Robinson',
#  'Phillip Dorsett II',
#  'Laquon Treadwell',
#  'Eli Rogers',
#  'Louis Murphy',
#  'Curtis Samuel',
#  'Chris Conley',
#  'Tommylee Lewis',
#  'Josh Reynolds',
#  'Jaydon Mickens',
#  'Brandon Marshall',
#  'Tre McBride III',
#  'Jordan Taylor',
#  'Brandon Tate',
#  'Kamar Aiken',
#  'Brenton Bersin',
#  'Josh Malone',
#  'Maurice Harris',
#  'Marvin Hall',
#  'Hunter Sharp',
#  'ArDarius Stewart',
#  'Travis Rudolph',
#  'Jaelen Strong',
#  'Freddie Martino',
#  'Mike Williams',
#  'Chad Hansen',
#  'Mike Thomas',
#  'Kaelin Clay',
#  'Kasen Williams',
#  'Chris Thompson',
#  'Trevor Davis',
#  'Justin Hunter',
#  'Michael Floyd',
#  'Breshad Perriman',
#  'Brian Quick',
#  'Tanner McEvoy',
#  'Willie Snead IV',
#  'Amara Darboh',
#  'Pharoh Cooper',
#  'Sammie Coates',
#  'Brittan Golden',
#  'Leonte Carroo',
#  'Bryce Treggs',
#  'Chad Williams',
#  'Markus Wheaton',
#  'Jared Abbrederis',
#  'Michael Clark',
#  'Quan Bray',
#  'Tanner Gentry',
#  'JoJo Natson',
#  'Noah Brown',
#  'Nick Williams',
#  'Ryan Switzer',
#  'Chris Matthews',
#  'Marcus Johnson',
#  'DeAndrew White',
#  'Griff Whalen',
#  'Jehu Chesson',
#  'Darius Powe',
#  'Jeff Janis',
#  'Cobi Hamilton',
#  'Kevin White',
#  'Cody Core',
#  'Isaiah McKenzie',
#  'Andre Roberts',
#  nan,
#  nan,
#  'Mike Evans',
#  'Jordy Nelson',
#  'Antonio Brown',
#  'Odell Beckham Jr.',
#  'T.Y. Hilton',
#  'Julio Jones',
#  'Davante Adams',
#  'Brandin Cooks',
#  'Michael Thomas',
#  'Doug Baldwin',
#  'Michael Crabtree',
#  'Amari Cooper',
#  'Tyrell Williams',
#  'Rishard Matthews',
#  'Tyreek Hill',
#  'Jarvis Landry',
#  'Larry Fitzgerald',
#  'Terrelle Pryor Sr.',
#  'Demaryius Thomas',
#  'Kelvin Benjamin',
#  'Emmanuel Sanders',
#  'Julian Edelman',
#  'Golden Tate',
#  ...]

# %%
#overall adp files

overall_adp_2021 = pd.read_csv('data/pre-season data/FantasyPros_2021_Overall_ADP_Rankings.csv')
overall_adp_2021['Year'] = '2021'

overall_adp_2020 = pd.read_csv('data/pre-season data/FantasyPros_2020_Overall_ADP_Rankings.csv')
overall_adp_2020['Year'] = '2020'

overall_adp_2019 = pd.read_csv('data/pre-season data/FantasyPros_2019_Overall_ADP_Rankings.csv')
overall_adp_2019['Year'] = '2019'

overall_adp_2018 = pd.read_csv('data/pre-season data/FantasyPros_2018_Overall_ADP_Rankings.csv')
overall_adp_2018['Year'] = '2018'

overall_adp_2017 = pd.read_csv('data/pre-season data/FantasyPros_2017_Overall_ADP_Rankings.csv')
overall_adp_2017['Year'] = '2017'

overall_adp_2016 = pd.read_csv('data/pre-season data/FantasyPros_2016_Overall_ADP_Rankings.csv')
overall_adp_2016['Year'] = '2016'

overall_adp_2015 = pd.read_csv('data/pre-season data/FantasyPros_2015_Overall_ADP_Rankings.csv')
overall_adp_2015['Year'] = '2015'

overall_adp_2014 = pd.read_csv('data/pre-season data/FantasyPros_2014_Overall_ADP_Rankings.csv')
overall_adp_2014['Year'] = '2014'

overall_adp_2013 = pd.read_csv('data/pre-season data/FantasyPros_2013_Overall_ADP_Rankings.csv')
overall_adp_2013['Year'] = '2013'

# %%
#end of season overall rankings 
overall_rankings_2021 = pd.read_csv('data/FantasyPros_Fantasy_Football_Points_PPR_2021.csv')
overall_rankings_2021['Year'] = '2021'

overall_rankings_2020 = pd.read_csv('data/FantasyPros_Fantasy_Football_Points_PPR_2020.csv')
overall_rankings_2020['Year'] = '2020'

overall_rankings_2019 = pd.read_csv('data/FantasyPros_Fantasy_Football_Points_PPR_2019.csv')
overall_rankings_2019['Year'] = '2019'

overall_rankings_2018 = pd.read_csv('data/FantasyPros_Fantasy_Football_Points_PPR_2018.csv')
overall_rankings_2018['Year'] = '2018'

overall_rankings_2017 = pd.read_csv('data/FantasyPros_Fantasy_Football_Points_PPR_2017.csv')
overall_rankings_2017['Year'] = '2017'

overall_rankings_2016 = pd.read_csv('data/FantasyPros_Fantasy_Football_Points_PPR_2016.csv')
overall_rankings_2016['Year'] = '2016'

overall_rankings_2015 = pd.read_csv('data/FantasyPros_Fantasy_Football_Points_PPR_2015.csv')
overall_rankings_2015['Year'] = '2015'

overall_rankings_2014 = pd.read_csv('data/FantasyPros_Fantasy_Football_Points_PPR_2014.csv')
overall_rankings_2014['Year'] = '2014'

overall_rankings_2013 = pd.read_csv('data/FantasyPros_Fantasy_Football_Points_PPR_2013.csv')
overall_rankings_2013['Year'] = '2013'

# %%
#giant cleaned datatable
adp_table = pd.concat([overall_adp_2021, overall_adp_2020, overall_adp_2019, overall_adp_2018, overall_adp_2017, overall_adp_2016, overall_adp_2015, overall_adp_2014, overall_adp_2013], axis=0)
overall_rankings_table = pd.concat([overall_rankings_2021, overall_rankings_2020, overall_rankings_2019, overall_rankings_2018, overall_rankings_2017, overall_rankings_2016, overall_rankings_2015, overall_rankings_2014, overall_rankings_2013], axis=0)
overall_merged = adp_table.merge(overall_rankings_table, how= 'outer', on = ['Player', 'Year'])

def clean_all_data(data_file):
    data_file2 = data_file.drop(columns=['RTSports', 'Sleeper', 'MFL', 'Fantrax', 'FFC', 'POS','Team_y', 'ESPN', 'Bye', 'Team_x'])
    data_file3 = data_file2.rename(columns = {"Rank_x": "Preseason_rank","Team_x":"Team", "Rank_y": "Postseason_rank", "AVG": "ADP", "Avg": "PPG"})
    data_file4 = data_file3.dropna(subset=['ADP'])
    return data_file4

def clean_data(data_file):
    data_file2 = data_file.drop(columns=['RTSports', 'Sleeper', 'MFL', 'Fantrax', 'FFC', 'POS','Team_y', 'ESPN', 'Bye', 'Team_x'])
    data_file3 = data_file2.rename(columns = {"Rank_x": "Preseason_rank","Team_x":"Team", "Rank_y": "Postseason_rank", "AVG": "ADP", "Avg": "PPG"})
    data_file4 = data_file3.loc[data_file3.Position == 'WR']
    data_file5 = data_file4.dropna(subset=['ADP'])
    return data_file5

overall_merged_data_clean = clean_data(overall_merged)
full = wr_table.merge(overall_merged_data_clean, how= 'outer', on = ['Player', 'Year'])
full = full.dropna(subset=['Player', 'ADP'])
wr_df = full.dropna(subset=['YAC/R'])

full_df = clean_all_data(overall_merged)

wr_df.to_csv("wr_df.csv",index=False)

full_df
# Out:
#       Preseason_rank               Player    ADP  Year  Postseason_rank  \
# 0                1.0  Christian McCaffrey    1.0  2021            168.0
# 1                2.0          Dalvin Cook    2.0  2021             68.0
# 2                3.0        Derrick Henry    3.0  2021             79.0
# 3                4.0         Alvin Kamara    4.0  2021             48.0
# 4                5.0      Ezekiel Elliott    5.0  2021             35.0
# ...              ...                  ...    ...   ...              ...
# 3914           476.0     Marvin Jones Jr.  480.0  2013             82.0
# 3915           477.0           Matt Moore  481.0  2013            654.0
# 3916           478.0      Fozzy Whittaker  482.0  2013            337.0
# 3917           479.0    Jerricho Cotchery  483.0  2013            104.0
# 3918           480.0        Domenik Hixon  484.0  2013            435.0
#
#      Position  Points  Games   PPG
# 0          RB   127.5    7.0  18.2
# 1          RB   206.3   13.0  15.9
# 2          RB   193.3    8.0  24.2
# 3          RB   234.7   13.0  18.1
# 4          RB   252.1   17.0  14.8
# ...       ...     ...    ...   ...
# 3914       WR   171.6   15.0  11.4
# 3915       QB    -1.9    1.0  -1.9
# 3916       RB    44.6   13.0   3.4
# 3917       WR   154.2   15.0  10.3
# 3918       WR    14.9   14.0   1.1
#
# [3883 rows x 9 columns]
